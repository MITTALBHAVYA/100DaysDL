# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/DailyDelhiClimateTrain.csv')

# %%
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df = df[['date','meantemp']]
df
# Out:
#             date   meantemp
# 0     2013-01-01  10.000000
# 1     2013-01-02   7.400000
# 2     2013-01-03   7.166667
# 3     2013-01-04   8.666667
# 4     2013-01-05   6.000000
# ...          ...        ...
# 1457  2016-12-28  17.217391
# 1458  2016-12-29  15.238095
# 1459  2016-12-30  14.095238
# 1460  2016-12-31  15.052632
# 1461  2017-01-01  10.000000
#
# [1462 rows x 2 columns]

# %%
plt.scatter(df['date'],df['meantemp'],color='red')

# %%
x1 = df['meantemp'].ewm(alpha=0.1).mean()
x1
# Out:
# 0       10.000000
# 1        8.631579
# 2        8.091021
# 3        8.258408
# 4        7.706918
#           ...
# 1457    17.554034
# 1458    17.322440
# 1459    16.999720
# 1460    16.805011
# 1461    16.124510
# Name: meantemp, Length: 1462, dtype: float64

# %%
df['ewma']=x1
df
# Out:
#             date   meantemp       ewma
# 0     2013-01-01  10.000000  10.000000
# 1     2013-01-02   7.400000   8.631579
# 2     2013-01-03   7.166667   8.091021
# 3     2013-01-04   8.666667   8.258408
# 4     2013-01-05   6.000000   7.706918
# ...          ...        ...        ...
# 1457  2016-12-28  17.217391  17.554034
# 1458  2016-12-29  15.238095  17.322440
# 1459  2016-12-30  14.095238  16.999720
# 1460  2016-12-31  15.052632  16.805011
# 1461  2017-01-01  10.000000  16.124510
#
# [1462 rows x 3 columns]

# %%
plt.scatter(df['date'],df['meantemp'],color='red')
plt.plot(df['date'],x1,color='black',label='alpha=0.1')
plt.legend()
plt.show()
